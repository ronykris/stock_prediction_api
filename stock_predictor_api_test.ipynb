# %% [markdown]
# <a href="https://colab.research.google.com/github/ronykris/stock_prediction_api/blob/master/stock_predictor_api_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# Replace with the URL provided by localtunnel
api_url = "https://sixty-experts-repeat.loca.lt/predict"

# Make a prediction request
response = requests.post(api_url, json={"days": 30})

if response.status_code == 200:
    predictions = response.json()
    print(f"Received {len(predictions)} predictions.")
    print("First prediction:", predictions[0])
else:
    print("Error:", response.status_code, response.text)
# Out:
# Received 28 predictions.
# First prediction: {'ds': '2024-08-26', 'yhat': 557.9830069468243, 'yhat_lower': 532.5900339980083, 'yhat_upper': 586.0414225467664}
